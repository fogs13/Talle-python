# %%
Departamento = input("Seleccione el departamento, recuerde 1)Armenia 2)Cundinamarca 3) Valle del cauca")
Departamento_t = int(Departamento)

if Departamento_t == 1:
    
    Ciudades_Armenia = input("Seleccione las ciudades 11) Armenia 12) Calarca 13) Quidio ")
    Ciudades_Armenia_i = int(Ciudades_Armenia)
    
    if  Ciudades_Armenia_i == 11:
        Platos_Tipicos1 = input("Seleccione los platos tipcos de su gusto 111) Bandeja Paisa 112) Mazamorra Bebida 113) Panecillos ")
        Platos_Tipicos1_i = int(Platos_Tipicos1)
        if Platos_Tipicos1_i == 111:
            print("se usan frijoles de la region e ingredientes frescos")
        elif Platos_Tipicos1_i == 112:
            print("La mazamorra es de maiz tierno")
        elif Platos_Tipicos1_i == 113:
            print("el panecillo es reposteria dela mejor calidad")
        else:
            print("Opcion invalida reinicie el programa")
    
    elif Ciudades_Armenia_i == 12:
        Platos_Tipicos2 = input("Seleccione los platos tipcos de su gusto 121) Sancocho de gallina 122) Hogao 113) Hogao de gallina ")
        Platos_Tipicos2_i = int(Platos_Tipicos2)
        if Platos_Tipicos2_i == 121:
            print("se usa una gallina tierna de la region")
        elif Platos_Tipicos2_i == 122:
            print("se usa mantequilla, cebolla, tomate  y ajo")
        elif Platos_Tipicos1_i == 113:
            print("se usa una gallina, cebolla, tomate mantequilla y ajo")
        else:
            print("Opcion invalida reinicie el programa")
         
    elif Ciudades_Armenia_i == 13:
        Platos_Tipicos3 = input("Seleccione los platos tipcos de su gusto 131) Carne molida y frijoles 132) chicharron 133) frijoles calentados ")
        Platos_Tipicos3_i = int(Platos_Tipicos3)
        if Platos_Tipicos3_i == 131:
            print("se usa la mejor carne de la region y arroz de primera calidad")
        elif Platos_Tipicos3_i == 132:
            print("se utiliza la mejor carne de bobinos y porcinos para este plato")
        elif Platos_Tipicos3_i == 133:
            print("se utilizan el grano de primera calidad")
        else:
            print("Opcion invalida reinicie el programa")
            
elif Departamento_t == 2:
    
    
    Ciudades_Cundinamarca = input("Seleccione las ciudades 21) Bogota 22) Soacha 23) Gacheta ")    
    Ciudades_Cundinamarca_i = int(Ciudades_Cundinamarca)
        
    if  Ciudades_Cundinamarca_i == 21:
        Platos_Tipicos21 = input("Seleccione los platos tipcos de su gusto 211) Ajiaco Santafereño 212) Chocolate Santafereño 213) Obleas ")
        Platos_Tipicos21_i = int(Platos_Tipicos21)
        if Platos_Tipicos21_i == 211:
            print("se utilizan papas criollas, pollo y verduras frescas")
        elif Platos_Tipicos21_i == 212:
            print("se utiliza chocolate tostado, canela y leche asi mismo se sirve con queso y pan")
        elif Platos_Tipicos21_i == 213:
            print("la masa de la oblea es de galleta y se utiliza arequipe preparado en la region")
        else:
            print("Opcion invalida reinicie el programa")

    elif Ciudades_Cundinamarca_i == 22:
        Platos_Tipicos22 = input("Seleccione los platos tipcos de su gusto 221) Almojabana 222) Arepa de chocolo 223) Arepa de maiz ")
        Platos_Tipicos22_i = int(Platos_Tipicos22)
        if Platos_Tipicos22_i == 221:
            print("se usa queso y maiz blenco y mantequilla")
        elif Platos_Tipicos22_i == 222:
            print("se usa mantequilla, cebolla, tomate  y ajo")
        elif Platos_Tipicos22_i == 223:
            print("se usa una gallina, cebolla, tomate mantequilla y ajo")
        else:
            print("Opcion invalida reinicie el programa")

    elif Ciudades_Cundinamarca_i == 23:
        Platos_Tipicos23 = input("Seleccione los platos tipcos de su gusto 231) Carne Asada 232) Picada de carne 233) Panderos ")
        Platos_Tipicos23_i = int(Platos_Tipicos23)
        if Platos_Tipicos23_i == 231:
            print("se usa la mejor carne de la region")
        elif Platos_Tipicos2_i == 232:
            print("se utiliza la mejor carne de bobinos, porcinos, pollo y chiguiro para este plato")
        elif Platos_Tipicos1_i == 233:
            print("se utilizan el grano de maiz de primera calidad e ingredientes fescos")
        else:
            print("Opcion invalida reinicie el programa")

elif Departamento_t == 3:
    
    
    Ciudades_Valle_del_Cauca = input("Seleccione las ciudades 31) Cali 32) Buenaventura 33) Palmira ")    
    Ciudades_Valle_del_Cauca_i = int(Ciudades_Valle_del_Cauca)
        
    if  Ciudades_Valle_del_Cauca_i == 31:
        Platos_Tipicos31 = input("Seleccione los platos tipcos de su gusto 311) Champus 312) Frijoles Vallunos 313) Pan de Bono ")
        Platos_Tipicos31_i = int(Platos_Tipicos31)
        if Platos_Tipicos31_i == 311:
            print("se utiliza lulo, patilla, guayaba y muchas mas frutas, totalmente frecas")
        elif Platos_Tipicos31_i == 312:
            print("se utiliza una variedad de frijol que se da en la region")
        elif Platos_Tipicos31_i == 313:
            print("Se utiliza queso, masa de maiz y mantequilla")
        else:
            print("Opcion invalida reinicie el programa")

    elif Ciudades_Valle_del_Cauca_i == 32:
        Platos_Tipicos32 = input("Seleccione los platos tipcos de su gusto 321) Arroz con coco 322) Ceviche con camaron 323) Camarones al ajillo ")
        Platos_Tipicos32_i = int(Platos_Tipicos32)
        if Platos_Tipicos32_i == 321:
            print("se usa coco, arroz blanco y los mejores ingredientes")
        elif Platos_Tipicos32_i == 322:
            print("se utiliza camaron, salsa de tomate y limon")
        elif Platos_Tipicos32_i == 323:
            print("se usa camarones, mayonesa y ajo")
        else:
            print("Opcion invalida reinicie el programa")

    elif Ciudades_Valle_del_Cauca_i == 33:
        Platos_Tipicos33 = input("Seleccione los platos tipcos de su gusto 331) Carne Asada gratinada 332) Picada de carne de tres carnes 333 Picada de maiz) ")
        Platos_Tipicos33_i = int(Platos_Tipicos33)
        if Platos_Tipicos33_i == 331:
            print("se usa la mejor carne de la region")
        elif Platos_Tipicos33_i == 332:
            print("se utiliza la mejor carne de bobinos, porcinos, pollo y chiguiro para este plato")
        elif Platos_Tipicos33_i == 333:
            print("se utilizan el grano de maiz de primera calidad e ingredientes fescos")
        else:
            print("Opcion invalida reinicie el programa")

else:
    print("reinicie esta aplicacion")
# Out:
# Seleccione el departamento, recuerde 1)Armenia 2)Cundinamarca 3) Valle del cauca1
# Seleccione las ciudades 11) Armenia 12) Calarca 13) Quidio 12
# Seleccione los platos tipcos de su gusto 121) Sancocho de gallina 122) Hogao 113) Hogao de gallina 122
# se usa mantequilla, cebolla, tomate  y ajo
