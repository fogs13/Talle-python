# %%
def Comida_tipica_Antioquia_1(V):
    return(print("\n En un almuerzo con amigos se disfruta de este plato tipico paisa"))

def Comida_tipica_Antioquia_2(V):
    return(print("\n Como postre se puede disfrutar de este delicioso manjar"))

def Comida_tipica_Antioquia_3(V):
    return(print("\n Es bastante apetecido despues de un buen almuerzo"))

def Comida_tipica_Antioquia_4(V):
    return( print("\n Es el plato ideal en los asados") )

def Fauna_Antioquia_1(V):
    return( print("\n Por las condiciones de la region con respecto al clima, asi mismo la altura. Esta ave esta presente dentro de este ecosistema") )

def Fauna_Antioquia_2(V):
    return( print("\n Esta ave es nativa dentro de este ecosistema, por tal motivo se ve en grandes bandadas"))

def Fauna_Antioquia_3(V):
    return( print("\n Este mamifero es particular por su anatomia y tamaño, se visualiza siempre dentro de la alta montaña"))

def Fauna_Antioquia_4(V):
    return(print("\n Este mamifero es de la familia de los felinos  particular por su anatomia y tamaño, se visualiza siempre dentro de la alta montaña"))

def Historia_Antioquia_1(V):
    return(print("\n Cecilio Metelo Pío fundó en el año 75 a. C. una población en Hispania (hoy España), a la que llamó Metellinum. Se trata de la actual Medellín de Extremadura, en la provincia de Badajoz. Un conde de esa localidad de Medellín de Extremadura, don Pedro Porto Carrero y Luna, presidente del Consejo de Indias de España, consiguió una autorización para llamar Medellín a una nueva fundación americana, debido a su interés en que otra recién fundada villa de ultramar fuese reconocida por la España peninsular."))

def Historia_Antioquia_2(V):
    return(print("\n El Valle de Aburrá, en donde hoy se asienta Medellín, fue visto por primera vez por los españoles el 24 de agosto de 1541, apenas 49 años después del arribo de Cristóbal Colon a las Bahamas, por una expedición de 32 hombres que venía en búsqueda de tierras y riquezas al mando de Jerónimo Luis Tejelo, quien a su vez obedecía órdenes del Mariscal Jorge Robledo; le nombraron -Valle de San Bartolomé de los Alcázares-, en honor tanto a San Bartolomé en su día según el santoral católico, como a los alcázares situados en España, que tenían cierto parecido a las chozas indígenas."))

def Historia_Antioquia_3(V):
    return(print("\n Durante el tiempo colonial Medellín no tuvo mucha importancia como centro urbano. El señorío de Antioquia lo ostentarían en esa época la ciudad madre de la región antioqueña, Santa Fe de Antioquia, en el occidente del departamento, la ciudad de Rionegro en el oriente, y los pueblos mineros de la zona del Bajo Cauca. Medellín sería una tranquila villa rodeada de hatos sin mayor importancia."))

def Historia_Antioquia_4(V):
    return(print("\n En consecuencia, Medellín no tendría tampoco mucho protagonismo en ese importante evento que representó la independencia nacional. Dicho protagonismo correspondería, en el departamento de Antioquia, a la ciudad de Rionegro y en general al Oriente antioqueño, con figuras heroicas de primer orden como el general José María Córdova."))

def Musica_Tipica_Antioquia_1(V):
    return(print("\n El pasillo apareció a la vida nacional por los años de la Colonia (hacia 1800) cuando la nueva sociedad burguesa buscó la ideación de un tipo de danza más acorde con el ambiente cortesano."))

Departamento = input("Seleccione el departamento, recuerde \n 1)Antioquia \n 2)Cundinamarca \n 3) Quindio \n 4) Valle \n" )
Departamento_t = int(Departamento)

if Departamento_t == 1:
    
    Ciudades_Antioquia = input("Seleccione las ciudades \n  11)  Medellin \n 12) Santafe de Antioquia \n 13) Rionegro \n 14) Yarumal \n")
    Ciudades_Antioquia_i = int(Ciudades_Antioquia)
    
    if  Ciudades_Antioquia_i == 11:
        Opciones_Interes1 = input("Seleccione la opcion de su interes \n 111) Gastronomia \n 112) Fauna \n 113) Datos Historicos \n 114) Musica \n")
        Opciones_Interes1_i = int(Opciones_Interes1)
        if Opciones_Interes1_i == 111:
            
            Comida_Tipica1 = input("Seleccione el plato de su interes \n 1111) Arroz con pollo \n 1112) Bananos asados \n 1113) Brevas con arequipe \n 1114) Morcilla Paisa \n")
            Comida_Tipica1_i = int(Comida_Tipica1)
            
            if Comida_Tipica1_i == 1111:
                Comida_tipica_Antioquia_1(1111)
                
            elif Comida_Tipica1_i == 1112:
                Comida_tipica_Antioquia_2(1112)
                
            elif Comida_Tipica1_i == 1113:
                Comida_tipica_Antioquia_3(1113)
                
            elif Comida_Tipica1_i == 1114:
                Comida_tipica_Antioquia_4(1114)   
            else:
                print("Opcion invalida reinicie el programa")
                
        elif Opciones_Interes1_i == 112:
              
            Fauna1 = input("Seleccione el animal de su interes \n 1121) Pajaro Carpintero \n 1122) Pajaros Azulejos \n 1123) Tigrillos \n 1124) Pumas \n")
            Fauna1_i = int(Fauna1)
            
            if Fauna1_i == 1121:
                Fauna_Antioquia_1(1121)
            elif Fauna1_i == 1122:
                Fauna_Antioquia_2(1122)   
            elif Fauna1_i == 1123:
                Fauna_Antioquia_3(1123)      
            elif Fauna1_i == 1124:
                Fauna_Antioquia_4(1124)       
            else:
                print("Opcion invalida reinicie el programa") 
                
        elif Opciones_Interes1_i == 113:
            
            Historia1 = input("Seleccione la informacion historica de su interes \n 1131) Origen Etimologico \n 1132) Conquista Española \n 1133) Colonia Española \n 1134) Independencia \n")
            Historia1_i = int(Historia1)
            
            if Historia1_i == 1131:
                Historia_Antioquia_1(1131)
                
            elif Historia1_i == 1132:
                Historia_Antioquia_2(1132)
            
            elif Historia1_i == 1133:
                Historia_Antioquia_3(1133)
                    
            elif Historia1_i == 1134:
                Historia_Antioquia_3(1134)
                
            else:
                print("Opcion invalida reinicie el programa")
                
        elif Opciones_Interes1_i == 114:
            
            Musica1 = input("\n Seleccione la informacion musical de su interes \n 1141) Pasillo \n 1142) Carrilera \n 1143) Trova Paisa \n 1144) Musica de cuerda \n")
            Musica1_i = int(Musica1)
            
            if Musica1_i == 1141:
                Musica_Tipica_Antioquia_1(1141)
            elif Musica1_i == 1142:
                print("\n Música de carrilera es el género musical popular de rumba o parranda, que se utilizó originalmente en Antioquia (Colombia) y en el denominado Eje Cafetero colombiano, tambien es conocida como Guascarrilera.")
            elif Musica1_i == 1143:
                print("\nLa Trova paisa tiene algunas peculiaridades, propias tanto de su región como del modo de ser, vivir y reír de los antioqueños.")      
            elif Musica1_i == 1144:
                print("\n  Está caracterizado, musicalmente, por ser bastante sencillo, pegajoso, popular, y apropiado para la rumba simple.")      
            else:
                print("Opcion invalida reinicie el programa")
# Out:
# Seleccione el departamento, recuerde
#  1)Antioquia
#  2)Cundinamarca
#  3) Quindio
#  4) Valle
# 1
# Seleccione las ciudades
#   11)  Medellin
#  12) Santafe de Antioquia
#  13) Rionegro
#  14) Yarumal
# 11
# Seleccione la opcion de su interes
#  111) Gastronomia
#  112) Fauna
#  113) Datos Historicos
#  114) Musica
# 112
# Seleccione el animal de su interes
#  1121) Pajaro Carpintero
#  1122) Pajaros Azulejos
#  1123) Tigrillos
#  1124) Pumas
# 1121
#
#  Por las condiciones de la region con respecto al clima, asi mismo la altura. Esta ave esta presente dentro de este ecosistema
